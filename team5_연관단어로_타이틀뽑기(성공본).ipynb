# %%
import pandas as pd
import re

# %% [markdown]
# #### 파일 입력

# %%
tmp = pd.read_csv('teample_1_result/special_word/economy_title.csv', sep=',', encoding='utf-8')

# %%
tmp.head()
# Out:
#    Unnamed: 0              날짜                                        제목
# 0           0  2018.11.13 (화)  에릭스도자기, '힐링요 건강조리기' 홍보 모델로 '요섹남' 이상민씨 발탁
# 1           1  2018.11.13 (화)             현대차, 장 중 10만원 붕괴…위기의 끝이 안 보인다
# 2           2  2018.11.13 (화)               배상철 한양대 류마티스내과 교수, 분쉬의학상 수상
# 3           3  2018.11.13 (화)         "급락은 남의 얘기"…최근 애널리스트가 목표가 올린 종목은?
# 4           4  2018.11.13 (화)   홍장표 주도 소주특위 “대기업 정규직 근로자 ‘나홀로 고임금’ 막아야”

# %% [markdown]
# #### 컬럼 정리

# %%
tmp.drop('Unnamed: 0',axis=1, inplace=True)

# %%
tmp.head()
# Out:
#                날짜                                        제목
# 0  2018.11.13 (화)  에릭스도자기, '힐링요 건강조리기' 홍보 모델로 '요섹남' 이상민씨 발탁
# 1  2018.11.13 (화)             현대차, 장 중 10만원 붕괴…위기의 끝이 안 보인다
# 2  2018.11.13 (화)               배상철 한양대 류마티스내과 교수, 분쉬의학상 수상
# 3  2018.11.13 (화)         "급락은 남의 얘기"…최근 애널리스트가 목표가 올린 종목은?
# 4  2018.11.13 (화)   홍장표 주도 소주특위 “대기업 정규직 근로자 ‘나홀로 고임금’ 막아야”

# %% [markdown]
# #### 핵심단어 들어간 타이틀 모으기 & 데이터프레임화하기

# %%
xlist = list()
x = '임금'

for i in range(len(tmp['제목'])):
    if x in tmp['제목'][i]:
        xlist.append(str(tmp['제목'][i]))
    else:
        pass
    xframe = pd.DataFrame({'제목' : xlist})

xframe
# Out:
#                                                     제목
# 0              홍장표 주도 소주특위 “대기업 정규직 근로자 ‘나홀로 고임금’ 막아야”
# 1             文정부 경제자문 인사들도 "최저임금 차등 적용하라" "현장 목소리 듣길"
# 2               "고용·경기 바로 좋아지진 않을 것… 최저임금은 이미 속도조절 됐다"
# 3                      '최저임금 타격' BGF리테일 3분기 영업익 19% 감소
# 4                     "통상임금 분쟁서 신의칙 인정 안되면 일자리 5만개 줄어"
# 5                                  [팀장칼럼] 2020년 최저임금은?
# 6                          최저임금의 불똥, 무이자할부 등 카드혜택 사라진다
# 7                                어도비, 40개 국가에서 남녀 동일임금
# 8                            급격한 최저임금 인상에 편의점 본사-점주 갈등
# 9       "대기업 정규직, 中企·비정규직과 격차 평균임금 1.8배 근속연수는 2.3배 길어"
# 10                 美, 근로자 임금 10년만에 최대폭 상승… 市場이 소득 끌어올려
# 11                 비정규직 비중 33%, 6년만에 최고치…임금은 정규직 절반 수준
# 12           [컨콜] 기아차 “작년 통상임금 비용 제외하면 영업이익 3200억원 감소”
# 13                                 소상공인도 이제 최저임금 결정 참여
# 14                          "최저임금 인상은 청년·자영업자의 제로섬 게임"
# 15               이재갑 고용부 장관 “최저임금, 경제가 감내할 수준 되도록 할 것”
# 16                 KDI "실업률 상승, 노동수요 축소 때문…최저임금 영향 있어"
# 17                       "연봉 5460만원도 주휴수당 때문에 최저임금 위반"
# 18                           기재부, KDI의 최저임금 쇼크 경고 묵살했다
# 19                            최저임금委 공익위원 9명중 8명이 '정부편'
# 20                       중소기업계 "임금수준 양극화 원인 주휴슈당 폐지해야"
# 21                      소상공인연합회 “정부가 대법원 판결·최저임금법 위반해”
# 22   '사회적 대화 중요성'만 강조한 고용부 장관...경총·대한상의 “최저임금 문제 해결해야”
# 23                        저임금 비판 받던 아마존, 최저시급 15달러로 인상
# 24                   김동연 "최저임금 지역별 차등 적용 검토 중…아이디어 차원"
# 25                        이낙연 "최저임금 차등 적용 여러가지 문제점 있어"
# 26                           대한상의, 최저임금 결정 개선방안 정부에 건의
# 27                            금호석유화학, 31년째 무분규 임금협상 체결
# 28                           삼성중공업, 3년치 임금협상 타결…기본급 동결
# 29                           BBQ, 포괄임금제 폐지...급여체계 전면개편
# ..                                                 ...
# 749                                中企人들 “최저임금 생각밖에 없다”
# 750                           정부 "최저임금 인상분 가맹본부가 분담해라"
# 751                “최저임금 부담 완화”… 임대료 인상률 상한·카드 수수료 낮춘다
# 752                   최저임금 반발 소상공인·영세 중기 달래기…정부 패키지 지원
# 753  김동연 “협력업체 최저임금에 신경써달라”… 정의선 “신사업 20조 투자… 4만500...
# 754                    최저임금 상승으로 인한 하도급업체 부담, 원사업자와 분담
# 755                   중기·소상공인, 대통령·여당 만남…최저임금 보완대책 나올까
# 756                             ‘최저임금 위반’ 사업주 명단 공개 논란
# 757          [김현주의 일상 톡톡] 최저임금 역풍 현실화…을도 아닌 정 알바생들의 눈물
# 758                    최저임금 해결사라는 일자리안정자금…소상공인에겐 그림의 떡
# 759                              “정부내서도 최저임금 문제점 지적해야”
# 760                     "최저임금 인상에 대한 정부의 막연한 기대 옳지 않다"
# 761                홍종학, 이틀째 최저임금 현장 방문…"필요한 소상공인 꼭 지원"
# 762                      홍종학 장관 "최저임금 인상, 중장기적으로 해결된다"
# 763                  김동연 "최저임금, 인간다운 삶 위한 것"…장관들 한 목소리
# 764                    김동연 "12월 서비스업 고용부진 최저임금 효과 아니다"
# 765                    정부 "김밥·치킨·햄버거 최저임금 편승인상 특별물가조사"
# 766                        최저임금 여파…편의점 신규 개점 줄고 폐점 늘었다
# 767                       납품·유통업체 최저임금 인상분 공동 부담…실효성은?
# 768                          최저임금 상승의 역설…아파트경비원 실직 잇따라
# 769                   "최저임금 오르니 꼼수 봇물"…"상여금 줄고 휴식 늘리고"
# 770                                 최저임금의 역습… 치킨값까지 들썩
# 771  [2018 韓 직장인의 애환-상] 최저임금 7530원 놓고 고용주vs근로자 동상이몽…왜?
# 772                          최저임금 보완대책…인건비 부담·가격인상 잡을까
# 773                    김동연 "최저임금 인상으로 어렵다고 종업원 해고 안 돼"
# 774                          최저임금 역풍 맞을라…정부도 알바생도 노심초사
# 775                      "최저임금 연착륙 위해 일자리 안정자금 최우선 추진"
# 776                      연초부터 ‘오른다’…최저임금 탓? 물가 다시 ‘꿈틀’
# 777                     알바생 10명중 7명 "최저임금 인상으로 구직난 걱정"
# 778                     [이코노 브리핑] 한국GM 노사 임금협상 잠정 합의 외
#
# [779 rows x 1 columns]

# %%
xframe.to_csv('teample_1_result/special_word/economy_sw_imgeum_utf.csv', sep=',', encoding='utf-8')
