# %%
from bs4 import BeautifulSoup 
from urllib.request import urlopen

import pandas as pd
import re

# %%
from konlpy.tag import Hannanum
from urllib.request import urlopen
from lxml import html
from collections import Counter
import nltk

import random
import pytagcloud      # requires Korean font support
import webbrowser
# Out:
# pygame 1.9.4
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %%
from matplotlib import font_manager, rc

font_name = font_manager.FontProperties(fname="C:/Windows/Fonts/malgun.ttf").get_name()
rc('font', family=font_name)

# %%
eco = pd.read_csv('./new_sorted/all_politics_commonword_freq_sorted_df.csv', sep=(','), encoding='utf-8')

# %%
eco2 = eco[['단어명','총빈도수']]
eco2.head()
# Out:
#    단어명  총빈도수
# 0   남북  1106
# 1  김정은  1076
# 2   회담   946
# 3  홍준표   828
# 4   국회   790

# %%
import numpy as np

# %%
eco3 = pd.np.array(eco2)
eco3
# Out:
# array([['남북', 1106],
#        ['김정은', 1076],
#        ['회담', 946],
#        ...,
#        ['금태섭', 8],
#        ['보전', 7],
#        ['편의', 7]], dtype=object)

# %%
data = dict(eco3)
len(data)
# Out:
# 978

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
wordcloud = WordCloud(font_path='C:/Windows/Fonts/malgun.ttf',
                      background_color='white'
                     ,relative_scaling =0.2).generate_from_frequencies(data)

# %%
plt.figure(figsize=(20,12))
plt.imshow(wordcloud)
plt.axis('off')
# Out:
# (-0.5, 399.5, 199.5, -0.5)

# %%
params = {
    "width"            : 800,
    "height"           : 600,
    "min_font_size"    : 2**3, 
    "max_font_size"    : 2**7, 
    "max_words"        : 100,
    "relative_scaling" : 0.2,
    # "font_path"        : 'C:/Windows/Fonts/malgun.ttf',
    "font_path"        : 'C:/Windows/Fonts/HMFMMUEX.TTC',
    "background_color" : 'white',
}

wordcolud = WordCloud(**params)
# wordcolud = wordcolud.generate(text) 
wordcolud = wordcolud.generate_from_frequencies(data) 

save_img = 'new_sorted/politic_all.png'

plt.figure(figsize=(24,16))
plt.imshow(wordcolud)
plt.axis('off')
plt.savefig(save_img)
